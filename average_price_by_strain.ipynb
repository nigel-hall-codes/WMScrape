# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

conn = sqlite3.connect("Medigreen.db")
cursor = conn.cursor()

# %%
q = """
    select product.name, avg(price.price) from producthasprice as php
    join product on product.id=php.productid
    join price on price.id=php.priceid
    where price.price > 0 and price.amount="eighth" and price.price < 60 
    
    group by product.name
"""

df = pd.read_sql(q, conn)
df.sort_values('avg(price.price)', ascending=False)
# Out:
#                                                    name  avg(price.price)
# 482                                              Ingrid             59.90
# 459                                       Helen Back #5             59.90
# 375                                           Gas Pedal             59.90
# 810                                             Red Roy             59.90
# 265                                 Cookie Kush // BOGO             59.71
# 681                            Orange Godfather // BOGO             59.71
# 899                                 Sour Diesel // BOGO             59.71
# 334                                     Fire OG // BOGO             59.71
# 420                                Gorilla Glue // BOGO             59.71
# 55                                 Amnesia Haze // BOGO             59.71
# 887                                      Slymer // BOGO             59.71
# 144                            Blue Silver Haze // BOGO             59.71
# ...
